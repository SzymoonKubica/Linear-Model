# %%
import pandas as pd 
import seaborn as sns

# %%
films= pd.read_csv('filmtv_movies.csv')

# %%
films.head()
# Out:
#    filmtv_id                                        title  year      genre  \
# 0          2  Bugs Bunny's Third Movie: 1001 Rabbit Tales  1982  Animation
# 1          3                    18 anni tra una settimana  1991      Drama
# 2         17                             Ride a Wild Pony  1976   Romantic
# 3         18                                        Diner  1982     Comedy
# 4         20              A che servono questi quattrini?  1942     Comedy
#
#    duration        country                             directors  \
# 0        76  United States  David Detiege, Art Davis, Bill Perez
# 1        98          Italy                         Luigi Perelli
# 2        91  United States                           Don Chaffey
# 3        95  United States                        Barry Levinson
# 4        85          Italy                        Esodo Pratelli
#
#                                               actors  avg_vote  critics_vote  \
# ...

# %%
films['genre'].unique()
# Out:
# array(['Animation', 'Drama', 'Romantic', 'Comedy', 'Spy', 'Crime',
#        'Thriller', 'Adventure', 'Documentary', 'Horror', 'Action',
#        'Western', 'Biography', 'Musical', 'Sci-Fi', 'War', 'Grotesque',
#        'Gangster', 'Fantasy', 'Mélo', 'Mythology', 'History', 'Erotico',
#        'Noir', 'Super-hero', 'Biblical', 'Sport', 'Sperimental', nan,
#        'Short Movie', 'Stand-up Comedy'], dtype=object)

# %%
map = {names:i for i,names in enumerate(films['genre'].unique())}

films['genre'] = films['genre'].replace(map)
# Out:
# C:\Users\szymo\AppData\Local\Temp\ipykernel_21512\911496928.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   films['genre'] = films['genre'].replace(map)

# %%
films['country']= films['country'].str.split(',').str[0]

# %%
mapCountry = {names:i for i, names in enumerate(films['country'].unique())}
films['country'] = films['country'].replace(mapCountry)
# Out:
# C:\Users\szymo\AppData\Local\Temp\ipykernel_21512\1728329494.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   films['country'] = films['country'].replace(mapCountry)

# %%
unique_names =films['directors'].unique()
name_to_value = {name: i for i, name in enumerate(unique_names)}

films['directors'] = films['directors'].map(name_to_value)

# %%
films.head()
# Out:
#    filmtv_id                                        title  year  genre  \
# 0          2  Bugs Bunny's Third Movie: 1001 Rabbit Tales  1982      0
# 1          3                    18 anni tra una settimana  1991      1
# 2         17                             Ride a Wild Pony  1976      2
# 3         18                                        Diner  1982      3
# 4         20              A che servono questi quattrini?  1942      3
#
#    duration  country  directors  \
# 0        76        0          0
# 1        98        1          1
# 2        91        0          2
# 3        95        0          3
# 4        85        1          4
#
#                                               actors  avg_vote  critics_vote  \
# 0                                                NaN       7.7          8.00
# 1  Kim Rossi Stuart, Simona Cavallari, Ennio Fant...       6.5          6.00
# 2  Michael Craig, John Meillon, Eva Griffith, Gra...       5.7          6.00
# ...

# %%
def PolecajkaFilmowaDirichlet(titl:str):
    filmRow = films[films['title'] == titl ]
    if len(filmRow) == 0:
        return "Movie not found"
    movies = films.drop(filmRow.index)

    filmYear = filmRow['year'].values
    filmCountry = filmRow['country'].values
    filmDirector = filmRow['directors'].values
    filmGenre = filmRow['genre'].values

    filmDist = movies['year'].values - filmYear
    countryDist = movies['country'].values - filmCountry
    directorDist = movies['directors'].values - filmDirector
    genreDist = movies['genre'].values - filmGenre
    
    moviesRecomend = movies

    #Dirichlet's metric 

    moviesRecomend['year'] = moviesRecomend['year'].apply(lambda x: 1 if x != 0 else 0) 
    moviesRecomend['country'] = moviesRecomend['country'].apply(lambda x: 1 if x != 0 else 0)
    moviesRecomend['directors'] = moviesRecomend['directors'].apply(lambda x: 1 if x != 0 else 0)
    moviesRecomend['genre'] = moviesRecomend['genre'].apply(lambda x: 1 if x != 0 else 0)

    moviesRecomend['summary'] = moviesRecomend['year'] + moviesRecomend['country'] + moviesRecomend['directors'] + moviesRecomend['genre']

    bestRecomendation = moviesRecomend['summary'].sort_values(ascending=True)

    bestFilmIndex = bestRecomendation.index[0]

    bestFilm = moviesRecomend['title'][0]

    return bestFilm

# %%
PolecajkaFilmowaDirichlet('Diner')
# Out:
# "Bugs Bunny's Third Movie: 1001 Rabbit Tales"

# %% [markdown]
# ML ver without description

# %%
films.head()
# Out:
#    filmtv_id                                        title  year  genre  \
# 0          2  Bugs Bunny's Third Movie: 1001 Rabbit Tales  1982      0
# 1          3                    18 anni tra una settimana  1991      1
# 2         17                             Ride a Wild Pony  1976      2
# 3         18                                        Diner  1982      3
# 4         20              A che servono questi quattrini?  1942      3
#
#    duration  country  directors  \
# 0        76        0          0
# 1        98        1          1
# 2        91        0          2
# 3        95        0          3
# 4        85        1          4
#
#                                               actors  avg_vote  critics_vote  \
# 0                                                NaN       7.7          8.00
# 1  Kim Rossi Stuart, Simona Cavallari, Ennio Fant...       6.5          6.00
# 2  Michael Craig, John Meillon, Eva Griffith, Gra...       5.7          6.00
# ...

# %%
films['actorsSplit'] = films['actors'].str.split(',')
films['actorsLen'] = films['actorsSplit'].apply(lambda x: len(x) if isinstance(x, list) else 0)
films['actorsLen'] = films['actorsLen'].fillna(0)
maxActors = films.loc[films['actorsLen'].idxmax()]
filmsActors = pd.DataFrame(films['actors'].to_list())

# %%
maxActors['actorsLen']
# Out:
# 89

# %%
def PolecajkaFilmowaNN(titl:str):
    pass
